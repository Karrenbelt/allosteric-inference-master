# %%
## Comparison of Gerosa, Core and Genome Scale Metabolic Models
% reset
import tellurium as te; te.setDefaultPlottingEngine('matplotlib')
% matplotlib inline
from optlang.symbolics import Zero
import cobra.util.solver as sutil
import os, re, cobra, shutil, cobra, time, json, pickle
import pandas as pd
import numpy as np
import scipy as sp
import matplotlib.pyplot as plt
import libsbml
from libsbml import *
# Out:
# Once deleted, variables cannot be recovered. Proceed (y/[n])? y
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>

# %%
### create time stamped output folder
stamp = time.strftime("%Y_%m_%d")
output = os.getcwd()+'/output/'+stamp+'/'
input_out = output+'input/'
if not os.path.isdir(os.getcwd()+'/output'):
    os.mkdir(os.getcwd()+'/output')
if not os.path.isdir(output):
    os.mkdir(output)
if not os.path.isdir(input_out):
    os.mkdir(input_out)

## save a copy of this script and all input files in the output folder
def copytree(src, dst, symlinks=False, ignore=None):
    for item in os.listdir(src):
        s = os.path.join(src, item)
        d = os.path.join(dst, item)
        if os.path.isdir(s):
            shutil.copytree(s, d, symlinks, ignore)
        else:
            shutil.copy2(s, d)

copytree(os.getcwd()+'/input/',input_out)
shutil.copy2(os.getcwd()+'/parsing_data.ipynb',output)
# Out:
# '/Users/Zarathustra/ETH/Mechanistic_modeling/Pipeline/output/2018_03_13/parsing_data.ipynb'

# %%
# encoding = ['utf-8', "cp1252", "ISO-8859-1"]
# df = pd.read_csv(input_out+'km.csv', encoding="ISO-8859-1")
# pd.read_csv(input_out+'regulation.csv', encoding="ISO-8859-1")
# pd.read_csv(input_out+'turnover.csv', encoding='utf-8')

# k = pd.read_csv('input/km.csv', index_col=0, encoding='latin-1')
km = pd.read_csv(input_out+'km.csv', index_col=0, encoding='ISO-8859-1')

value_col = 'KM_Value'
organism = 'Escherichia coli'
km_coli = km[km['Organism'].str.lower() == organism.lower()]
print((km_coli[value_col] > 0).sum())
# Out:
# 20613

# %%
# convert EC_number to bigg.reaction
# generate table with bigg.reaction_bigg.metabolite as id

km_filtered = km_coli[(pd.isnull(km_coli['Commentary'])) |
      ((km_coli['Commentary'].str.find('mutant') == -1) &
       (km_coli['Commentary'].str.find('mutation') == -1) &
       (km_coli['Commentary'].str.find('variant') == -1) &
       (km_coli['Commentary'].str.find('genetically engineered') == -1))]

print((km_filtered[value_col] > 0).sum())
# Out:
# 11855

# %%
km = km_filtered[pd.notnull(km_filtered['bigg.metabolite'])].copy()
km['bigg.metabolite'] = km['bigg.metabolite'].str.lower()
km_val = km[km[value_col] > 0]
print(km_val.shape[0])
print(km_val.groupby(('bigg.metabolite', 'EC_number')).first().shape[0])
print(km_val.groupby('bigg.metabolite').first().shape[0])
print(km_val.groupby('EC_number').first().shape[0])
# Out:
# 9534
# 1644
# 542
# 649

# %%
km_val.groupby(('bigg.metabolite', 'EC_number')).first()
# Out:
#                                    Organism  LigandID   KM_Value  \
# bigg.metabolite EC_number
# 10fthf          2.1.2.2    Escherichia coli     16154    0.07750
# 12ppd__s        1.1.1.77   Escherichia coli     20321    1.25000
# 14dhncoa        3.1.2.28   Escherichia coli     85376    0.00800
# 1pyr5c          1.2.1.41   Escherichia coli     45501    2.50000
#                 1.5.1.2    Escherichia coli      1804    0.14000
# 23camp          3.1.4.16   Escherichia coli       942    0.49000
#                 3.1.4.37   Escherichia coli       942    0.49000
#                 3.1.4.55   Escherichia coli       942    0.11000
# 23ccmp          3.1.4.55   Escherichia coli      7083    0.14000
# 23cgmp          3.1.4.16   Escherichia coli      5089    1.60000
#                 3.1.4.37   Escherichia coli      5089    1.60000
#                 3.1.4.55   Escherichia coli      5089    0.31000
# 23dappa         4.1.99.1   Escherichia coli     46195    0.60000
#                 4.3.1.15   Escherichia coli     20756    0.03000
# 23ddhb          1.3.1.28   Escherichia coli     29329    0.30000
# 23dhb           2.7.7.58   Escherichia coli      3773    0.00270
#                 6.3.2.14   Escherichia coli      1367    0.00250
# 23dhdp          1.17.1.8   Escherichia coli      4593    0.00900
# 24dhhed         4.1.2.20   Escherichia coli     18858    0.10000
#                 4.1.2.52   Escherichia coli     10416    0.35000
#                 4.1.2.53   Escherichia coli     10416    0.10000
# 26dap__m        4.1.1.20   Escherichia coli     20910    1.70000
#                 5.1.1.7    Escherichia coli      4267    0.36000
#                 6.3.2.13   Escherichia coli      1400    0.03600
# 26dap_ll        5.1.1.7    Escherichia coli      8243    0.16000
# 2ahbut          1.1.1.86   Escherichia coli      5230    0.00200
# 2cpr5p          4.1.1.48   Escherichia coli       967    0.00034
# 2dda7p          4.2.3.4    Escherichia coli      4386    0.00055
# 2ddg6p          4.1.2.14   Escherichia coli      1596    0.06000
# 2ddglcn         2.7.1.45   Escherichia coli      1172    1.00000
# ...                                     ...       ...        ...
# uri             2.7.1.48   Escherichia coli       261    0.35000
#                 3.2.2.3    Escherichia coli       261    0.40800
#                 3.2.2.8    Escherichia coli       261    0.12000
# utp             2.3.1.157  Escherichia coli        65    0.10000
#                 2.7.1.105  Escherichia coli        65    0.78000
#                 2.7.1.11   Escherichia coli        65    5.10000
#                 2.7.1.7    Escherichia coli        65    2.00000
#                 2.7.4.22   Escherichia coli        65    0.04600
#                 2.7.7.23   Escherichia coli        65    0.10000
#                 2.7.7.38   Escherichia coli        65    0.88000
#                 2.7.7.9    Escherichia coli        65    0.05800
#                 6.3.4.2    Escherichia coli        65    0.02700
#                 6.3.4.4    Escherichia coli        65    2.06000
# val__l          2.6.1.42   Escherichia coli       246    2.70000
#                 6.1.1.9    Escherichia coli       246    0.00430
#                 6.3.2.8    Escherichia coli       835   70.00000
# xan             2.4.2.22   Escherichia coli       234    0.03050
#                 2.4.2.29   Escherichia coli       234    0.22400
# xmp             6.3.5.2    Escherichia coli      1007    0.02900
# xtp             6.3.4.4    Escherichia coli      1941    0.38800
# xtsn            2.4.2.1    Escherichia coli      1222    0.05100
#                 3.2.2.3    Escherichia coli      1222    0.45400
# xu1p__d         4.1.2.19   Escherichia coli     30788    0.20000
# xu5p__d         2.2.1.1    Escherichia coli       644    0.16000
# xyl__d          1.1.5.2    Escherichia coli       115   17.00000
#                 5.1.3.3    Escherichia coli       115   23.00000
# xylt            2.7.1.17   Escherichia coli       416  127.00000
# xylu_d          2.7.1.16   Escherichia coli       715   16.00000
#                 2.7.1.17   Escherichia coli       715    0.29000
# zn2             3.6.3.5    Escherichia coli        14    0.00510
#
#                                                                   Commentary  \
# bigg.metabolite EC_number
# 10fthf          2.1.2.2                                               pH 8.5
# 12ppd__s        1.1.1.77                                              pH 9.5
# 14dhncoa        3.1.2.28                                        pH 7.0, 25°C
# 1pyr5c          1.2.1.41                                                 NaN
#                 1.5.1.2                                            with NADH
# 23camp          3.1.4.16                                            +/- 0.04
#                 3.1.4.37                                            +/- 0.04
#                 3.1.4.55                      pH 7.2, 25°C, presence of Mn2+
# 23ccmp          3.1.4.55                      pH 7.2, 25°C, presence of Mn2+
# 23cgmp          3.1.4.16                                            +/- 0.22
#                 3.1.4.37                                            +/- 0.22
#                 3.1.4.55                      pH 7.2, 25°C, presence of Mn2+
# 23dappa         4.1.99.1                                      strain B/1t7-A
#                 4.3.1.15   wild-type, pH and temperature not specified in...
# 23ddhb          1.3.1.28                                                 NaN
# 23dhb           2.7.7.58                                        pH 9.0, 37°C
#                 6.3.2.14                      pH 7.8, 25°C, recombinant EntE
# 23dhdp          1.17.1.8                                                 NaN
# 24dhhed         4.1.2.20                        data for Ni2+-activated YfaU
#                 4.1.2.52   using H2O as solvent, in the presence of 0.5 m...
#                 4.1.2.53                        pH 8.0, 25°C, Ni2+-activated
# 26dap__m        4.1.1.20                                                 NaN
#                 5.1.1.7                              LL-diaminoheptanedioate
#                 6.3.2.13                                                 NaN
# 26dap_ll        5.1.1.7                                                  NaN
# 2ahbut          1.1.1.86                                        pH 7.4, 25°C
# 2cpr5p          4.1.1.48                                    wild-type enzyme
# 2dda7p          4.2.3.4                                   at 20°C and pH 8.5
# 2ddg6p          4.1.2.14                                        pH 7.6, 25°C
# 2ddglcn         2.7.1.45                                                 NaN
# ...                                                                      ...
# uri             2.7.1.48                                        pH 7.8, 37°C
#                 3.2.2.3          pH 7.2, 32°C, recombinant His-tagged enzyme
#                 3.2.2.8    wild type enzyme, in 50 mM HEPES buffer (pH 7....
# utp             2.3.1.157                         uridyltransferase activity
#                 2.7.1.105                         pH 8.2, 30°C, strain DF903
#                 2.7.1.11                                        pH 7.2, 30°C
#                 2.7.1.7                                         pH 7.5, 25°C
#                 2.7.4.22                      pH 7.4, 30°C, wild-type enzyme
#                 2.7.7.23                                        pH 8.2, 37°C
#                 2.7.7.38                                        pH 8.0, 37°C
#                 2.7.7.9                                         pH 7.8, 37°C
#                 6.3.4.2                            pH 8.0, 25°C, without GTP
#                 6.3.4.4                                            wild-type
# val__l          2.6.1.42                                        pH 8.0, 25°C
#                 6.1.1.9                 with wild-type tRNAVal, pH 7.5, 37°C
#                 6.3.2.8                                                  NaN
# xan             2.4.2.22                                                 NaN
#                 2.4.2.29                      37°C, pH 7.3, wild-type enzyme
# xmp             6.3.5.2                             40°C, pH 8.0, NF-ATPP/DD
# xtp             6.3.4.4                                            wild-type
# xtsn            2.4.2.1                       pH 7.1, 25°C, wild-type enzyme
#                 3.2.2.3          pH 7.2, 32°C, recombinant His-tagged enzyme
# xu1p__d         4.1.2.19                                                 NaN
# xu5p__d         2.2.1.1                                                  NaN
# xyl__d          1.1.5.2    recombinant wild-type enzyme with bound Mg2+, ...
#                 5.1.3.3                                                  NaN
# xylt            2.7.1.17                                    wild type enzyme
# xylu_d          2.7.1.16                                        22°C, pH 7.5
#                 2.7.1.17                                    wild type enzyme
# zn2             3.6.3.5                                       wild-type ZntA
#
#                                Literature  \
# bigg.metabolite EC_number
# 10fthf          2.1.2.2            485718
# 12ppd__s        1.1.1.77           287312
# 14dhncoa        3.1.2.28           729928
# 1pyr5c          1.2.1.41           390307
#                 1.5.1.2            392126
# 23camp          3.1.4.16           652555
#                 3.1.4.37           652555
#                 3.1.4.55           719851
# 23ccmp          3.1.4.55           719851
# 23cgmp          3.1.4.16           652555
#                 3.1.4.37           652555
#                 3.1.4.55           719851
# 23dappa         4.1.99.1            37341
#                 4.3.1.15           729988
# 23ddhb          1.3.1.28           390631
# 23dhb           2.7.7.58           643530
#                 6.3.2.14           726950
# 23dhdp          1.17.1.8   390617, 390618
# 24dhhed         4.1.2.20           691007
#                 4.1.2.52           725493
#                 4.1.2.53           691007
# 26dap__m        4.1.1.20             4110
#                 5.1.1.7              2140
#                 6.3.2.13       1039, 1276
# 26dap_ll        5.1.1.7        2140, 2155
# 2ahbut          1.1.1.86           639177
# 2cpr5p          4.1.1.48             4609
# 2dda7p          4.2.3.4            718818
# 2ddg6p          4.1.2.14           664300
# 2ddglcn         2.7.1.45           636960
# ...                                   ...
# uri             2.7.1.48           641644
#                 3.2.2.3            731361
#                 3.2.2.8            696258
# utp             2.3.1.157          288685
#                 2.7.1.105          640323
#                 2.7.1.11           640522
#                 2.7.1.7            641894
#                 2.7.4.22           698858
#                 2.7.7.23           288685
#                 2.7.7.38           645227
#                 2.7.7.9            643738
#                 6.3.4.2            648997
#                 6.3.4.4              1561
# val__l          2.6.1.42           640012
#                 6.1.1.9            653865
#                 6.3.2.8              1290
# xan             2.4.2.22           638006
#                 2.4.2.29           678191
# xmp             6.3.5.2              1360
# xtp             6.3.4.4              1561
# xtsn            2.4.2.1            489693
#                 3.2.2.3            731361
# xu1p__d         4.1.2.19             5066
# xu5p__d         2.2.1.1    486023, 486026
# xyl__d          1.1.5.2            654865
#                 5.1.3.3              2364
# xylt            2.7.1.17           675423
# xylu_d          2.7.1.16           641013
#                 2.7.1.17           675423
# zn2             3.6.3.5            246929
#
#                                                                   LigandName  \
# bigg.metabolite EC_number
# 10fthf          2.1.2.2                      (6R)-N10-formyltetrahydrofolate
# 12ppd__s        1.1.1.77                                   L-1,2-propanediol
# 14dhncoa        3.1.2.28                           1-hydroxy-2-naphthoyl-CoA
# 1pyr5c          1.2.1.41                      DL-pyrroline-5-carboxylic acid
#                 1.5.1.2                            L-pyrroline-5-carboxylate
# 23camp          3.1.4.16                                          2',3'-cAMP
#                 3.1.4.37                                          2',3'-cAMP
#                 3.1.4.55                                          2',3'-cAMP
# 23ccmp          3.1.4.55                                          2',3'-cCMP
# 23cgmp          3.1.4.16                                          2',3'-cGMP
#                 3.1.4.37                                          2',3'-cGMP
#                 3.1.4.55                                          2',3'-cGMP
# 23dappa         4.1.99.1                    alpha,beta-diaminopropionic acid
#                 4.3.1.15                             L-2,3-diaminopropanoate
# 23ddhb          1.3.1.28                   2,3-Dihydro-2,3-dihydroxybenzoate
# 23dhb           2.7.7.58                           2,3-Dihydroxybenzoic acid
#                 6.3.2.14                               2,3-dihydroxybenzoate
# 23dhdp          1.17.1.8                                 dihydrodipicolinate
# 24dhhed         4.1.2.20                  4-hydroxy-2-ketoheptane-1,7-dioate
#                 4.1.2.52                   4-hydroxy-2-oxoheptane-1,7-dioate
#                 4.1.2.53                   4-hydroxy-2-oxoheptane-1,7-dioate
# 26dap__m        4.1.1.20                     meso-2,6-diamininoheptanedioate
#                 5.1.1.7                            meso-diaminoheptanedioate
#                 6.3.2.13                       meso-2,6-diaminoheptanedioate
# 26dap_ll        5.1.1.7                              LL-diaminoheptanedioate
# 2ahbut          1.1.1.86                           2-aceto-2-hydroxybutyrate
# 2cpr5p          4.1.1.48   1-(2-carboxyphenylamino)-1-deoxy-D-ribulose-5-...
# 2dda7p          4.2.3.4       3-deoxy-D-arabino-hept-2-ulosonate 7-phosphate
# 2ddg6p          4.1.2.14           2-dehydro-3-deoxy-D-gluconate 6-phosphate
# 2ddglcn         2.7.1.45                       2-dehydro-3-deoxy-D-gluconate
# ...                                                                      ...
# uri             2.7.1.48                                             uridine
#                 3.2.2.3                                              uridine
#                 3.2.2.8                                              uridine
# utp             2.3.1.157                                                UTP
#                 2.7.1.105                                                UTP
#                 2.7.1.11                                                 UTP
#                 2.7.1.7                                                  UTP
#                 2.7.4.22                                                 UTP
#                 2.7.7.23                                                 UTP
#                 2.7.7.38                                                 UTP
#                 2.7.7.9                                                  UTP
#                 6.3.4.2                                                  UTP
#                 6.3.4.4                                                  UTP
# val__l          2.6.1.42                                            L-valine
#                 6.1.1.9                                             L-valine
#                 6.3.2.8                                                L-Val
# xan             2.4.2.22                                            xanthine
#                 2.4.2.29                                            xanthine
# xmp             6.3.5.2                                                  XMP
# xtp             6.3.4.4                                                  XTP
# xtsn            2.4.2.1                                           xanthosine
#                 3.2.2.3                                           xanthosine
# xu1p__d         4.1.2.19                              L-xylulose 1-phosphate
# xu5p__d         2.2.1.1                               D-xylulose 5-phosphate
# xyl__d          1.1.5.2                                             D-xylose
#                 5.1.3.3                                             D-xylose
# xylt            2.7.1.17                                             xylitol
# xylu_d          2.7.1.16                                          D-xylulose
#                 2.7.1.17                                          D-xylulose
# zn2             3.6.3.5                                                 Zn2+
#
#                                chebiID KEGG_ID  \
# bigg.metabolite EC_number
# 10fthf          2.1.2.2    CHEBI:15637  C00234
# 12ppd__s        1.1.1.77   CHEBI:29002  C02917
# 14dhncoa        3.1.2.28           NaN     NaN
# 1pyr5c          1.2.1.41    CHEBI:1372  C04322
#                 1.5.1.2      CHEBI:371  C03912
# 23camp          3.1.4.16   CHEBI:27844  C02353
#                 3.1.4.37   CHEBI:27844  C02353
#                 3.1.4.55   CHEBI:27844  C02353
# 23ccmp          3.1.4.55   CHEBI:27652  C02354
# 23cgmp          3.1.4.16   CHEBI:28181  C06194
#                 3.1.4.37   CHEBI:28181  C06194
#                 3.1.4.55   CHEBI:28181  C06194
# 23dappa         4.1.99.1   CHEBI:58468     NaN
#                 4.3.1.15   CHEBI:57721     NaN
# 23ddhb          1.3.1.28   CHEBI:15941     NaN
# 23dhb           2.7.7.58   CHEBI:18026  C00196
#                 6.3.2.14   CHEBI:18026  C00196
# 23dhdp          1.17.1.8   CHEBI:48052  C03340
# 24dhhed         4.1.2.20   CHEBI:73089  C05601
#                 4.1.2.52   CHEBI:73089  C05601
#                 4.1.2.53   CHEBI:73089  C05601
# 26dap__m        4.1.1.20   CHEBI:57791     NaN
#                 5.1.1.7    CHEBI:57791     NaN
#                 6.3.2.13   CHEBI:57791     NaN
# 26dap_ll        5.1.1.7    CHEBI:57609     NaN
# 2ahbut          1.1.1.86     CHEBI:982  C00659
# 2cpr5p          4.1.1.48   CHEBI:29112  C01302
# 2dda7p          4.2.3.4    CHEBI:18150  C04691
# 2ddg6p          4.1.2.14   CHEBI:15925  C04442
# 2ddglcn         2.7.1.45   CHEBI:17032  C00204
# ...                                ...     ...
# uri             2.7.1.48   CHEBI:16704  C00299
#                 3.2.2.3    CHEBI:16704  C00299
#                 3.2.2.8    CHEBI:16704  C00299
# utp             2.3.1.157  CHEBI:15713  C00075
#                 2.7.1.105  CHEBI:15713  C00075
#                 2.7.1.11   CHEBI:15713  C00075
#                 2.7.1.7    CHEBI:15713  C00075
#                 2.7.4.22   CHEBI:15713  C00075
#                 2.7.7.23   CHEBI:15713  C00075
#                 2.7.7.38   CHEBI:15713  C00075
#                 2.7.7.9    CHEBI:15713  C00075
#                 6.3.4.2    CHEBI:15713  C00075
#                 6.3.4.4    CHEBI:15713  C00075
# val__l          2.6.1.42   CHEBI:57762     NaN
#                 6.1.1.9    CHEBI:57762     NaN
#                 6.3.2.8    CHEBI:57762     NaN
# xan             2.4.2.22   CHEBI:48517  C00385
#                 2.4.2.29   CHEBI:48517  C00385
# xmp             6.3.5.2    CHEBI:15652  C00655
# xtp             6.3.4.4    CHEBI:10049  C00700
# xtsn            2.4.2.1    CHEBI:18107  C01762
#                 3.2.2.3    CHEBI:18107  C01762
# xu1p__d         4.1.2.19   CHEBI:28566  C06441
# xu5p__d         2.2.1.1    CHEBI:16332  C00231
# xyl__d          1.1.5.2    CHEBI:53455  C00181
#                 5.1.3.3    CHEBI:53455  C00181
# xylt            2.7.1.17   CHEBI:17151  C00379
# xylu_d          2.7.1.16   CHEBI:17140  C00310
#                 2.7.1.17   CHEBI:17140  C00310
# zn2             3.6.3.5    CHEBI:29105  C00038
#
#                                                                         Name
# bigg.metabolite EC_number
# 10fthf          2.1.2.2                            10-Formyltetrahydrofolate
# 12ppd__s        1.1.1.77                                (S)-Propane-1,2-diol
# 14dhncoa        3.1.2.28                                                 NaN
# 1pyr5c          1.2.1.41                      Delta1-Pyrroline-5-carboxylate
#                 1.5.1.2                        (S)-1-Pyrroline-5-carboxylate
# 23camp          3.1.4.16                                    2',3'-Cyclic AMP
#                 3.1.4.37                                    2',3'-Cyclic AMP
#                 3.1.4.55                                    2',3'-Cyclic AMP
# 23ccmp          3.1.4.55                                    2',3'-Cyclic CMP
# 23cgmp          3.1.4.16                                    2',3'-Cyclic GMP
#                 3.1.4.37                                    2',3'-Cyclic GMP
#                 3.1.4.55                                    2',3'-Cyclic GMP
# 23dappa         4.1.99.1                                                 NaN
#                 4.3.1.15                                                 NaN
# 23ddhb          1.3.1.28                                                 NaN
# 23dhb           2.7.7.58                               2,3-Dihydroxybenzoate
#                 6.3.2.14                               2,3-Dihydroxybenzoate
# 23dhdp          1.17.1.8                           L-2,3-Dihydrodipicolinate
# 24dhhed         4.1.2.20                       4-Hydroxy-2-oxo-heptanedioate
#                 4.1.2.52                       4-Hydroxy-2-oxo-heptanedioate
#                 4.1.2.53                       4-Hydroxy-2-oxo-heptanedioate
# 26dap__m        4.1.1.20                                                 NaN
#                 5.1.1.7                                                  NaN
#                 6.3.2.13                                                 NaN
# 26dap_ll        5.1.1.7                                                  NaN
# 2ahbut          1.1.1.86                          2-Aceto-2-hydroxybutanoate
# 2cpr5p          4.1.1.48   1-(2-Carboxyphenylamino)-1-deoxy-D-ribulose 5-...
# 2dda7p          4.2.3.4    2-Dehydro-3-deoxy-D-arabino-heptonate 7-phosphate
# 2ddg6p          4.1.2.14             2-Dehydro-3-deoxy-6-phospho-D-gluconate
# 2ddglcn         2.7.1.45                       2-Dehydro-3-deoxy-D-gluconate
# ...                                                                      ...
# uri             2.7.1.48                                             Uridine
#                 3.2.2.3                                              Uridine
#                 3.2.2.8                                              Uridine
# utp             2.3.1.157                                                UTP
#                 2.7.1.105                                                UTP
#                 2.7.1.11                                                 UTP
#                 2.7.1.7                                                  UTP
#                 2.7.4.22                                                 UTP
#                 2.7.7.23                                                 UTP
#                 2.7.7.38                                                 UTP
#                 2.7.7.9                                                  UTP
#                 6.3.4.2                                                  UTP
#                 6.3.4.4                                                  UTP
# val__l          2.6.1.42                                                 NaN
#                 6.1.1.9                                                  NaN
#                 6.3.2.8                                                  NaN
# xan             2.4.2.22                                            Xanthine
#                 2.4.2.29                                            Xanthine
# xmp             6.3.5.2                              Xanthosine 5'-phosphate
# xtp             6.3.4.4                                                  XTP
# xtsn            2.4.2.1                                           Xanthosine
#                 3.2.2.3                                           Xanthosine
# xu1p__d         4.1.2.19                              L-Xylulose 1-phosphate
# xu5p__d         2.2.1.1                               D-Xylulose 5-phosphate
# xyl__d          1.1.5.2                                             D-Xylose
#                 5.1.3.3                                             D-Xylose
# xylt            2.7.1.17                                             Xylitol
# xylu_d          2.7.1.16                                          D-Xylulose
#                 2.7.1.17                                          D-Xylulose
# zn2             3.6.3.5                                          Zinc cation
#
# [1644 rows x 9 columns]
